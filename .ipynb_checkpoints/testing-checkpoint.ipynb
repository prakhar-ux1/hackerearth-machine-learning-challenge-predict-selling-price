# %%
import numpy as np
import seaborn as sns
import pandas as pd

# %%
df1=pd.read_csv("train.csv")

# %%
print(df1.shape,df1.index,df1.columns)
# Out:
# (6368, 15) RangeIndex(start=0, stop=6368, step=1) Index(['Product_id', 'Stall_no', 'instock_date', 'Market_Category',
#        'Customer_name', 'Loyalty_customer', 'Product_Category', 'Grade',
#        'Demand', 'Discount_avail', 'charges_1', 'charges_2 (%)',
#        'Minimum_price', 'Maximum_price', 'Selling_Price'],
#       dtype='object')

# %%
df1
# Out:
#             Product_id  Stall_no             instock_date  Market_Category  \
# 0     BRAE2NF6JA5GUEXG      37.0  2015-08-22 18:36:12.000                2
# 1     TUNE8SFB6RJN2HSD      38.0  2016-03-27 21:19:13.000               24
# 2     BRAEAR7WZPQGPBZU       9.0  2015-08-18 19:25:22.000              447
# 3     WATDZ2ZQ8JPDHCTJ      50.0  2016-03-28 21:53:01.000               23
# 4     JWSEBUKYQPMBZ3RK       7.0  2016-03-29 22:58:53.000               63
# ...                ...       ...                      ...              ...
# 6363  WATE7VE2D62VEKW8      17.0  2016-03-28 19:55:43.000               24
# 6364  SHOEF9G8Z4ZXF6WE      21.0  2015-02-11 15:09:26.000               55
# 6365  PBXEB9ZQ7HHCFXYG      36.0  2015-11-19 17:29:21.000              358
# 6366  NKCEAGXHRYTNTMG7      27.0  2015-12-08 04:19:33.000              452
# 6367  CAGE53FSAFWZRHFF      11.0  2016-01-20 19:45:35.000               58
#
# ...

# %%
 df1.isnull().sum()
# Out:
# Product_id            0
# Stall_no              5
# instock_date          0
# Market_Category       0
# Customer_name       211
# Loyalty_customer      0
# Product_Category      0
# Grade                 0
# Demand                0
# Discount_avail       38
# charges_1           198
# charges_2 (%)       205
# Minimum_price        38
# Maximum_price       343
# Selling_Price        41
# dtype: int64

# %%
df1[df1['Selling_Price'].isnull()&df1['Minimum_price'].isnull()&df1['Maximum_price']].sum()
# Out:
# Product_id          0.0
# Stall_no            0.0
# instock_date        0.0
# Market_Category     0.0
# Customer_name       0.0
# Loyalty_customer    0.0
# Product_Category    0.0
# Grade               0.0
# Demand              0.0
# Discount_avail      0.0
# charges_1           0.0
# charges_2 (%)       0.0
# Minimum_price       0.0
# Maximum_price       0.0
# Selling_Price       0.0
# dtype: float64

# %%
df1[df1['Selling_Price'].isnull()&df1['Minimum_price'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Product_id, Stall_no, instock_date, Market_Category, Customer_name, Loyalty_customer, Product_Category, Grade, Demand, Discount_avail, charges_1, charges_2 (%), Minimum_price, Maximum_price, Selling_Price]
# Index: []

# %%
df1[]
# Out:
#   File "<ipython-input-16-b8d13dc3286a>", line 1
#     df1[Selling_Price,axis=1]
#                           ^
# SyntaxError: invalid syntax
